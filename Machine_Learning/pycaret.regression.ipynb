# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('C:\python\Apple\Machine_Learning\Apple_attribute+S.csv')

# %%
from pycaret.classification import *
s = setup(data, target = 'Sweetness')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [12], line 2
#       1 from pycaret.regression import *
# ----> 2 s = setup(data, target = 'Sweetness')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\regression\functional.py:593, in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, transform_target, transform_target_method, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     591 exp = _EXPERIMENT_CLASS()
#     592 set_current_experiment(exp)
# --> 593 return exp.setup(
#     594     data=data,
#     595     data_func=data_func,
#     596     target=target,
#     597     index=index,
#     598     train_size=train_size,
#     599     test_data=test_data,
#     600     ordinal_features=ordinal_features,
#     601     numeric_features=numeric_features,
#     602     categorical_features=categorical_features,
#     603     date_features=date_features,
#     604     text_features=text_features,
#     605     ignore_features=ignore_features,
#     606     keep_features=keep_features,
#     607     preprocess=preprocess,
#     608     create_date_columns=create_date_columns,
#     609     imputation_type=imputation_type,
#     610     numeric_imputation=numeric_imputation,
#     611     categorical_imputation=categorical_imputation,
#     612     iterative_imputation_iters=iterative_imputation_iters,
#     613     numeric_iterative_imputer=numeric_iterative_imputer,
#     614     categorical_iterative_imputer=categorical_iterative_imputer,
#     615     text_features_method=text_features_method,
#     616     max_encoding_ohe=max_encoding_ohe,
#     617     encoding_method=encoding_method,
#     618     rare_to_value=rare_to_value,
#     619     rare_value=rare_value,
#     620     polynomial_features=polynomial_features,
#     621     polynomial_degree=polynomial_degree,
#     622     low_variance_threshold=low_variance_threshold,
#     623     group_features=group_features,
#     624     group_names=group_names,
#     625     remove_multicollinearity=remove_multicollinearity,
#     626     multicollinearity_threshold=multicollinearity_threshold,
#     627     bin_numeric_features=bin_numeric_features,
#     628     remove_outliers=remove_outliers,
#     629     outliers_method=outliers_method,
#     630     outliers_threshold=outliers_threshold,
#     631     transformation=transformation,
#     632     transformation_method=transformation_method,
#     633     normalize=normalize,
#     634     normalize_method=normalize_method,
#     635     pca=pca,
#     636     pca_method=pca_method,
#     637     pca_components=pca_components,
#     638     feature_selection=feature_selection,
#     639     feature_selection_method=feature_selection_method,
#     640     feature_selection_estimator=feature_selection_estimator,
#     641     n_features_to_select=n_features_to_select,
#     642     transform_target=transform_target,
#     643     transform_target_method=transform_target_method,
#     644     custom_pipeline=custom_pipeline,
#     645     custom_pipeline_position=custom_pipeline_position,
#     646     data_split_shuffle=data_split_shuffle,
#     647     data_split_stratify=data_split_stratify,
#     648     fold_strategy=fold_strategy,
#     649     fold=fold,
#     650     fold_shuffle=fold_shuffle,
#     651     fold_groups=fold_groups,
#     652     n_jobs=n_jobs,
#     653     use_gpu=use_gpu,
#     654     html=html,
#     655     session_id=session_id,
#     656     system_log=system_log,
#     657     log_experiment=log_experiment,
#     658     experiment_name=experiment_name,
#     659     experiment_custom_tags=experiment_custom_tags,
#     660     log_plots=log_plots,
#     661     log_profile=log_profile,
#     662     log_data=log_data,
#     663     verbose=verbose,
#     664     memory=memory,
#     665     profile=profile,
#     666     profile_kwargs=profile_kwargs,
#     667 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\regression\oop.py:741, in RegressionExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, transform_target, transform_target_method, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     725 self._prepare_folds(
#     726     fold_strategy=fold_strategy,
#     727     fold=fold,
#     728     fold_shuffle=fold_shuffle,
#     729     fold_groups=fold_groups,
#     730 )
#     731 self._prepare_column_types(
#     732     ordinal_features=ordinal_features,
#     733     numeric_features=numeric_features,
#    (...)
#     738     keep_features=keep_features,
#     739 )
# --> 741 self._set_exp_model_engines(
#     742     container_default_engines=get_container_default_engines(),
#     743     engine=engine,
#     744 )
#     746 # Preprocessing ============================================ >>
#     747
#     748 # Initialize empty pipeline
#     749 self.pipeline = InternalPipeline(
#     750     steps=[("placeholder", None)],
#     751     memory=self.memory,
#     752 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2929, in _TabularExperiment._set_exp_model_engines(self, container_default_engines, engine)
#    2926 for key in container_default_engines:
#    2927     # If provided by user, then use that, else get from the defaults
#    2928     eng = engine.get(key, container_default_engines.get(key))
# -> 2929     self._set_engine(estimator=key, engine=eng, severity="error")
#    2931 return self
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2895, in _TabularExperiment._set_engine(self, estimator, engine, severity)
#    2890     self.logger.info(
#    2891         f"Engine successfully changes for model '{estimator}' to '{engine}'."
#    2892     )
#    2894 # Need to do this, else internal class variables are not reset with new engine.
# -> 2895 self._set_all_models()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2785, in _TabularExperiment._set_all_models(self)
#    2777 def _set_all_models(self) -> "_TabularExperiment":
#    2778     """Set all available models
#    2779
#    2780     Returns
#    (...)
#    2783         The experiment object to allow chaining of methods
#    2784     """
# -> 2785     self._all_models, self._all_models_internal = self._get_models()
#    2786     return self
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\regression\oop.py:62, in RegressionExperiment._get_models(self, raise_errors)
#      59 def _get_models(self, raise_errors: bool = True) -> Tuple[dict, dict]:
#      60     all_models = {
#      61         k: v
# ---> 62         for k, v in get_all_reg_model_containers(
#      63             self, raise_errors=raise_errors
#      64         ).items()
#      65         if not v.is_special
#      66     }
#      67     all_models_internal = get_all_reg_model_containers(
#      68         self, raise_errors=raise_errors
#      69     )
#      70     return all_models, all_models_internal
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\containers\models\regression.py:2000, in get_all_model_containers(experiment, raise_errors)
#    1997 def get_all_model_containers(
#    1998     experiment: Any, raise_errors: bool = True
#    1999 ) -> Dict[str, RegressorContainer]:
# -> 2000     return pycaret.containers.base_container.get_all_containers(
#    2001         globals(), experiment, RegressorContainer, raise_errors
#    2002     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\containers\base_container.py:119, in get_all_containers(container_globals, experiment, type_var, raise_errors)
#     117 if hasattr(obj, "active") and not obj.active:
#     118     continue
# --> 119 instance = obj(experiment)
#     120 if instance.active:
#     121     model_containers.append(instance)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\containers\models\regression.py:1518, in XGBRegressorContainer.__init__(self, experiment)
#    1516 np.random.seed(experiment.seed)
#    1517 if _check_soft_dependencies("xgboost", extra="models", severity="warning"):
# -> 1518     import xgboost
#    1519 else:
#    1520     self.active = False
#
# File c:\python\Apple\Machine_Learning\xgboost.py:6
#       4 from sklearn.preprocessing import PolynomialFeatures
#       5 from sklearn.preprocessing import StandardScaler
# ----> 6 from xgboost import XGBRegressor
#       9 at = pd.read_csv('./Machine_Learning/Apple_attribute.csv')
#      10 apple_attribute = at.to_numpy()
#
# ImportError: cannot import name 'XGBRegressor' from partially initialized module 'xgboost' (most likely due to a circular import) (c:\python\Apple\Machine_Learning\xgboost.py)

# %%
best = compare_models()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 best = compare_models()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\utils\generic.py:950, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     948     if globals_d[name] is None:
#     949         raise ValueError(message)
# --> 950 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\regression\functional.py:806, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, engine, verbose, parallel)
#     670 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     671 def compare_models(
#     672     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     687     parallel: Optional[ParallelBackend] = None,
#     688 ):
#     690     """
#     691     This function trains and evaluates performance of all estimators available in the
#     692     model library using cross validation. The output of this function is a score grid
#    (...)
#     804
#     805     """
# --> 806     return _CURRENT_EXPERIMENT.compare_models(
#     807         include=include,
#     808         exclude=exclude,
#     809         fold=fold,
#     810         round=round,
#     811         cross_validation=cross_validation,
#     812         sort=sort,
#     813         n_select=n_select,
#     814         budget_time=budget_time,
#     815         turbo=turbo,
#     816         errors=errors,
#     817         fit_kwargs=fit_kwargs,
#     818         groups=groups,
#     819         experiment_custom_tags=experiment_custom_tags,
#     820         engine=engine,
#     821         verbose=verbose,
#     822         parallel=parallel,
#     823     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\regression\oop.py:1119, in RegressionExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, engine, verbose, parallel)
#    1116         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1118 try:
# -> 1119     return_values = super().compare_models(
#    1120         include=include,
#    1121         exclude=exclude,
#    1122         fold=fold,
#    1123         round=round,
#    1124         cross_validation=cross_validation,
#    1125         sort=sort,
#    1126         n_select=n_select,
#    1127         budget_time=budget_time,
#    1128         turbo=turbo,
#    1129         errors=errors,
#    1130         fit_kwargs=fit_kwargs,
#    1131         groups=groups,
#    1132         experiment_custom_tags=experiment_custom_tags,
#    1133         verbose=verbose,
#    1134         parallel=parallel,
#    1135         caller_params=caller_params,
#    1136     )
#    1138 finally:
#    1139     if engine is not None:
#    1140         # Reset the models back to the default engines
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:528, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     365 def compare_models(
#     366     self,
#     367     include: Optional[
#    (...)
#     387     caller_params: Optional[dict] = None,
#     388 ) -> List[Any]:
#     390     """
#     391     This function train all the models available in the model library and scores them
#     392     using Cross Validation. The output prints a score grid with Accuracy,
#    (...)
#     526
#     527     """
# --> 528     self._check_setup_ran()
#     530     if parallel is not None:
#     531         return self._parallel_compare_models(parallel, caller_params, turbo=turbo)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycaret\internal\pycaret_experiment\pycaret_experiment.py:118, in _PyCaretExperiment._check_setup_ran(self)
#     107 """Checks to see if setup has been run or not. If it has not been run, then
#     108 an error is raised. Useful for operations that require setup to be run before
#     109 they can be executed. e.g. in some experiments, setup must be run first before
#    (...)
#     115     If setup has not been run.
#     116 """
#     117 if not self._setup_ran:
# --> 118     raise RuntimeError(
#     119         "This function/method requires the users to run setup() first."
#     120         "\nMore info: https://pycaret.gitbook.io/docs/get-started/quickstart"
#     121     )
#
# RuntimeError: This function/method requires the users to run setup() first.
# More info: https://pycaret.gitbook.io/docs/get-started/quickstart

# %%
plot_model(best)

# %%
evaluate_model(best)

# %%
from pycaret.regression import RegressionExperiment
exp1 = RegressionExperiment()

# %%
exp1.setup(data, target = 'Sweetness')
# Out:
# <style type="text/css">
# #T_f5832_row7_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f5832_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5832_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5832_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f5832_row0_col1" class="data row0 col1" >4166</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f5832_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f5832_row1_col1" class="data row1 col1" >Sweetness</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f5832_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f5832_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f5832_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_f5832_row3_col1" class="data row3 col1" >(200, 295)</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f5832_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_f5832_row4_col1" class="data row4 col1" >(139, 295)</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f5832_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_f5832_row5_col1" class="data row5 col1" >(61, 295)</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f5832_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_f5832_row6_col1" class="data row6 col1" >294</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f5832_row7_col0" class="data row7 col0" >Preprocess</td>
#       <td id="T_f5832_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f5832_row8_col0" class="data row8 col0" >Imputation type</td>
#       <td id="T_f5832_row8_col1" class="data row8 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f5832_row9_col0" class="data row9 col0" >Numeric imputation</td>
#       <td id="T_f5832_row9_col1" class="data row9 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f5832_row10_col0" class="data row10 col0" >Categorical imputation</td>
#       <td id="T_f5832_row10_col1" class="data row10 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f5832_row11_col0" class="data row11 col0" >Low variance threshold</td>
#       <td id="T_f5832_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f5832_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_f5832_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f5832_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_f5832_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f5832_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_f5832_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f5832_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_f5832_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f5832_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_f5832_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f5832_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_f5832_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f5832_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f5832_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_f5832_row18_col1" class="data row18 col1" >6bc4</td>
#     </tr>
#   </tbody>
# </table>

# %%
dir(exp1)
# Out:
# ['USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_custom_pipeline',
#  '_all_metrics',
#  '_all_models',
#  '_all_models_internal',
#  '_available_plots',
#  '_balance',
#  '_bin_numerical_features',
#  '_calculate_metrics',
#  '_check_environment',
#  '_check_setup_ran',
#  '_choose_better',
#  '_convert_log_experiment',
#  '_create_app_predict_kwargs',
#  '_create_model',
#  '_create_model_with_cv',
#  '_create_model_without_cv',
#  '_date_feature_engineering',
#  '_encode_target_column',
#  '_encoding',
#  '_feature_selection',
#  '_fxs',
#  '_get_cv_n_folds',
#  '_get_cv_splitter',
#  '_get_default_plots_to_log',
#  '_get_final_model_from_pipeline',
#  '_get_greater_is_worse_columns',
#  '_get_groups',
#  '_get_metric_by_name_or_id',
#  '_get_metrics',
#  '_get_model_id',
#  '_get_model_name',
#  '_get_models',
#  '_get_return_train_score_columns_for_display',
#  '_get_return_train_score_indices_for_logging',
#  '_get_setup_display',
#  '_gpu_n_jobs_param',
#  '_group_features',
#  '_highlight_and_round_model_results',
#  '_highlight_models',
#  '_initialize_setup',
#  '_is_multiclass',
#  '_is_unsupervised',
#  '_iterative_imputation',
#  '_log_model',
#  '_low_variance',
#  '_ml_usecase',
#  '_normalization',
#  '_pack_for_remote',
#  '_parallel_compare_models',
#  '_pca',
#  '_plot_model',
#  '_polynomial_features',
#  '_prepare_column_types',
#  '_prepare_dataset',
#  '_prepare_folds',
#  '_prepare_train_test',
#  '_process_sort',
#  '_profile',
#  '_register_setup_params',
#  '_remote',
#  '_remove_multicollinearity',
#  '_remove_outliers',
#  '_set_all_metrics',
#  '_set_all_models',
#  '_set_engine',
#  '_set_exp_model_engines',
#  '_set_index',
#  '_set_up_logging',
#  '_setup_params',
#  '_setup_ran',
#  '_simple_imputation',
#  '_target_transformation',
#  '_text_embedding',
#  '_transformation',
#  '_unpack_at_remote',
#  '_validate_log_experiment',
#  'add_metric',
#  'all_allowed_engines',
#  'automl',
#  'blend_models',
#  'check_fairness',
#  'compare_models',
#  'convert_model',
#  'create_api',
#  'create_app',
#  'create_docker',
#  'create_model',
#  'dashboard',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'deep_check',
#  'deploy_model',
#  'display_container',
#  'eda',
#  'ensemble_model',
#  'evaluate_model',
#  'exp_id',
#  'exp_model_engines',
#  'exp_name_log',
#  'finalize_model',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'get_allowed_engines',
#  'get_config',
#  'get_engine',
#  'get_leaderboard',
#  'get_logs',
#  'get_metrics',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'index',
#  'interpret_model',
#  'load_config',
#  'load_model',
#  'log_plots_param',
#  'logger',
#  'logging_param',
#  'master_model_container',
#  'memory',
#  'models',
#  'n_jobs_param',
#  'pipeline',
#  'plot_model',
#  'plot_model_check_display_format_',
#  'predict_model',
#  'pull',
#  'remove_metric',
#  'save_config',
#  'save_model',
#  'seed',
#  'set_config',
#  'setup',
#  'stack_models',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'transform_target_method',
#  'transform_target_param',
#  'tune_model',
#  'variable_keys',
#  'variables',
#  'verbose',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed']

# %%
exp1.compare_models()
# Out:
# <style type="text/css">
# #T_beda3_ th {
#   text-align: left;
# }
# #T_beda3_row0_col0, #T_beda3_row1_col0, #T_beda3_row1_col1, #T_beda3_row1_col2, #T_beda3_row1_col3, #T_beda3_row1_col4, #T_beda3_row1_col5, #T_beda3_row1_col6, #T_beda3_row2_col0, #T_beda3_row2_col1, #T_beda3_row2_col2, #T_beda3_row2_col3, #T_beda3_row2_col4, #T_beda3_row2_col5, #T_beda3_row2_col6, #T_beda3_row3_col0, #T_beda3_row3_col1, #T_beda3_row3_col2, #T_beda3_row3_col3, #T_beda3_row3_col4, #T_beda3_row3_col5, #T_beda3_row3_col6, #T_beda3_row4_col0, #T_beda3_row4_col1, #T_beda3_row4_col2, #T_beda3_row4_col3, #T_beda3_row4_col4, #T_beda3_row4_col5, #T_beda3_row4_col6, #T_beda3_row5_col0, #T_beda3_row5_col1, #T_beda3_row5_col2, #T_beda3_row5_col3, #T_beda3_row5_col4, #T_beda3_row5_col5, #T_beda3_row5_col6, #T_beda3_row6_col0, #T_beda3_row6_col1, #T_beda3_row6_col2, #T_beda3_row6_col3, #T_beda3_row6_col4, #T_beda3_row6_col5, #T_beda3_row6_col6, #T_beda3_row7_col0, #T_beda3_row7_col1, #T_beda3_row7_col2, #T_beda3_row7_col3, #T_beda3_row7_col4, #T_beda3_row7_col5, #T_beda3_row7_col6, #T_beda3_row8_col0, #T_beda3_row8_col1, #T_beda3_row8_col2, #T_beda3_row8_col3, #T_beda3_row8_col4, #T_beda3_row8_col5, #T_beda3_row8_col6, #T_beda3_row9_col0, #T_beda3_row9_col1, #T_beda3_row9_col2, #T_beda3_row9_col3, #T_beda3_row9_col4, #T_beda3_row9_col5, #T_beda3_row9_col6, #T_beda3_row10_col0, #T_beda3_row10_col1, #T_beda3_row10_col2, #T_beda3_row10_col3, #T_beda3_row10_col4, #T_beda3_row10_col5, #T_beda3_row10_col6, #T_beda3_row11_col0, #T_beda3_row11_col1, #T_beda3_row11_col2, #T_beda3_row11_col3, #T_beda3_row11_col4, #T_beda3_row11_col5, #T_beda3_row11_col6, #T_beda3_row12_col0, #T_beda3_row12_col1, #T_beda3_row12_col2, #T_beda3_row12_col3, #T_beda3_row12_col4, #T_beda3_row12_col5, #T_beda3_row12_col6, #T_beda3_row13_col0, #T_beda3_row13_col1, #T_beda3_row13_col2, #T_beda3_row13_col3, #T_beda3_row13_col4, #T_beda3_row13_col5, #T_beda3_row13_col6, #T_beda3_row14_col0, #T_beda3_row14_col1, #T_beda3_row14_col2, #T_beda3_row14_col3, #T_beda3_row14_col4, #T_beda3_row14_col5, #T_beda3_row14_col6, #T_beda3_row15_col0, #T_beda3_row15_col1, #T_beda3_row15_col2, #T_beda3_row15_col3, #T_beda3_row15_col4, #T_beda3_row15_col5, #T_beda3_row15_col6, #T_beda3_row16_col0, #T_beda3_row16_col1, #T_beda3_row16_col2, #T_beda3_row16_col3, #T_beda3_row16_col4, #T_beda3_row16_col5, #T_beda3_row16_col6, #T_beda3_row17_col0, #T_beda3_row17_col1, #T_beda3_row17_col2, #T_beda3_row17_col3, #T_beda3_row17_col4, #T_beda3_row17_col5, #T_beda3_row17_col6, #T_beda3_row18_col0, #T_beda3_row18_col1, #T_beda3_row18_col2, #T_beda3_row18_col3, #T_beda3_row18_col4, #T_beda3_row18_col5, #T_beda3_row18_col6 {
#   text-align: left;
# }
# #T_beda3_row0_col1, #T_beda3_row0_col2, #T_beda3_row0_col3, #T_beda3_row0_col4, #T_beda3_row0_col5, #T_beda3_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_beda3_row0_col7, #T_beda3_row1_col7, #T_beda3_row2_col7, #T_beda3_row3_col7, #T_beda3_row4_col7, #T_beda3_row5_col7, #T_beda3_row6_col7, #T_beda3_row7_col7, #T_beda3_row8_col7, #T_beda3_row9_col7, #T_beda3_row10_col7, #T_beda3_row12_col7, #T_beda3_row13_col7, #T_beda3_row14_col7, #T_beda3_row15_col7, #T_beda3_row16_col7, #T_beda3_row17_col7, #T_beda3_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_beda3_row11_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_beda3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_beda3_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_beda3_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_beda3_row0_col1" class="data row0 col1" >0.9230</td>
#       <td id="T_beda3_row0_col2" class="data row0 col2" >1.3651</td>
#       <td id="T_beda3_row0_col3" class="data row0 col3" >1.1301</td>
#       <td id="T_beda3_row0_col4" class="data row0 col4" >0.1683</td>
#       <td id="T_beda3_row0_col5" class="data row0 col5" >0.0804</td>
#       <td id="T_beda3_row0_col6" class="data row0 col6" >0.0709</td>
#       <td id="T_beda3_row0_col7" class="data row0 col7" >0.3160</td>
#     </tr>
#     <tr>
#       <th id="T_beda3_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_beda3_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_beda3_row1_col1" class="data row1 col1" >0.9561</td>
#       <td id="T_beda3_row1_col2" class="data row1 col2" >1.4568</td>
#       <td id="T_beda3_row1_col3" class="data row1 col3" >1.1607</td>
#       <td id="T_beda3_row1_col4" class="data row1 col4" >0.1295</td>
#       <td id="T_beda3_row1_col5" class="data row1 col5" >0.0819</td>
#       <td id="T_beda3_row1_col6" class="data row1 col6" >0.0726</td>
#       <td id="T_beda3_row1_col7" class="data row1 col7" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_beda3_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_beda3_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_beda3_row2_col1" class="data row2 col1" >0.9589</td>
#       <td id="T_beda3_row2_col2" class="data row2 col2" >1.4551</td>
#       <td id="T_beda3_row2_col3" class="data row2 col3" >1.1710</td>
#       <td id="T_beda3_row2_col4" class="data row2 col4" >0.1208</td>
#       <td id="T_beda3_row2_col5" class="data row2 col5" >0.0830</td>
#       <td id="T_beda3_row2_col6" class="data row2 col6" >0.0738</td>
#       <td id="T_beda3_row2_col7" class="data row2 col7" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_beda3_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_beda3_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_beda3_row3_col1" class="data row3 col1" >0.9919</td>
#       <td id="T_beda3_row3_col2" class="data row3 col2" >1.4523</td>
#       <td id="T_beda3_row3_col3" class="data row3 col3" >1.1806</td>
#       <td id="T_beda3_row3_col4" class="data row3 col4" >0.1084</td>
#       <td id="T_beda3_row3_col5" class="data row3 col5" >0.0841</td>
#       <td id="T_beda3_row3_col6" class="data row3 col6" >0.0763</td>
#       <td id="T_beda3_row3_col7" class="data row3 col7" >21.0390</td>
#     </tr>
#     <tr>
#       <th id="T_beda3_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_beda3_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_beda3_row4_col1" class="data row4 col1" >0.9660</td>
#       <td id="T_beda3_row4_col2" class="data row4 col2" >1.4611</td>
#       <td id="T_beda3_row4_col3" class="data row4 col3" >1.1795</td>
#       <td id="T_beda3_row4_col4" class="data row4 col4" >0.1064</td>
#       <td id="T_beda3_row4_col5" class="data row4 col5" >0.0836</td>
#       <td id="T_beda3_row4_col6" class="data row4 col6" >0.0742</td>
#       <td id="T_beda3_row4_col7" class="data row4 col7" >0.9550</td>
#     </tr>
#     <tr>
#       <th id="T_beda3_level0_row5" class="row_heading level0 row5" >en</th>
#       <td id="T_beda3_row5_col0" class="data row5 col0" >Elastic Net</td>
#       <td id="T_beda3_row5_col1" class="data row5 col1" >0.9657</td>
#       <td id="T_beda3_row5_col2" class="data row5 col2" >1.4807</td>
#       <td id="T_beda3_row5_col3" class="data row5 col3" >1.1828</td>
#       <td id="T_beda3_row5_col4" class="data row5 col4" >0.0949</td>
#       <td id="T_beda3_row5_col5" class="data row5 col5" >0.0835</td>
#       <td id="T_beda3_row5_col6" class="data row5 col6" >0.0739</td>
#       <td id="T_beda3_row5_col7" class="data row5 col7" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_beda3_level0_row6" class="row_heading level0 row6" >lasso</th>
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]
# AdaBoostRegressor(random_state=4166)
